# %%
import pandas as pd

# %%
df = pd.read_csv("naver_news_dataset.csv")
df
# Out:
#                                      title  \
# 0            내일 낮 투표소 갈 땐 가볍게 입으세요…아침에는 쌀쌀
# 1                                 사전투표소 설치
# 2                불출마 두 의원이 함께한 여행서 터놓은 속마음
# 3     장애 오빠 돌보러 온 여동생까지…50대 남매 아파트서 화재로 숨져
# 4        함께 술마시던 지인 흉기로 살해 50대 구속…법원 도주 우려
# ...                                    ...
# 3495   영남대 대학기업가센터 지원사업 성과평가 2년 연속 ‘최우수대학’
# 3496                대구·경북 파견 누적 의료인력 3561명
# 3497          MBC 검언유착 녹취록 일부 제출…대검 추가로 내라
# 3498          고용허가제 외국인 노동자 체류기간 50일 일괄 연장
# 3499                              회사가 큰가요?
#
#                                                contents category
# 0     서울·경기·강원 영서 오전 미세먼지 나쁨 제21대 국회의원 선거일이자 수요일인 15...       환경
# 1     제21대 국회의원 선거 사전투표를 하루 앞둔 9일 오후 부산 연제구청 2층 대강당에...       지역
# 2     12일 밤 11시 5분 방송되는 SBS스페셜에서는 제21대 총선 불출마 선언으로 국...       언론
# 3     아파트에서 불이 나 장애가 있는 50대 남성과 돌보러 온 여동생이 함께 숨지는 사고...     사건사고
# 4     함께 술을 마시던 지인을 흉기로 찔러 살해해 긴급체포됐던 50대 남성이 구속됐다. ...     사건사고
# ...                                                 ...      ...
# 3495  영남대가 최근 대학기업가센터 지원사업 성과평가에서 최우수대학에 선정됐다.대학기업가센...       교육
# 3496  대구·경북 파견 누적 의료인력 3561명. 의사 1621명 간호인력 1486명 임상...     사건사고
# 3497  본격 진상조사 앞두고 신경전…채널A 자체조사 마치는대로 제출 채널A와 검사장 간 유...       언론
# 3498  고용허가제 적용을 받는 외국인 노동자의 국내 취업활동기간이 50일 일괄 연장된다. ...       노동
# 3499                                        ⓒ 세상을 보는 눈        교육
#
# [3500 rows x 3 columns]

# %%
category = set(df["category"]) #중복 제거
category #네이버 뉴스에 어떤 카테고리들이 있는지 보기
# Out:
# {'교육', '노동', '사건사고', '식품/의료', '언론', '지역', '환경'}

# %%
# 각각의 네이버 뉴스를 500개씩 제작
for c in category:
    print(c, len(df[df["category"] == c]))
# Out:
# 교육 500
# 식품/의료 500
# 노동 500
# 언론 500
# 환경 500
# 지역 500
# 사건사고 500

# %%
category_len = [] # 각 카테고리별로 존재하는 뉴스의 개수를 찾는 코드
for c in category:
    category_len.append(len(df[df["category"] == c]))
category_len
# Out:
# [500, 500, 500, 500, 500, 500, 500]

# %%
# !pip install matplotlib

# %%
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
#위에는 그래프를 그리는데 필요한 라이브러리들

import platform
#os를 알기위한 것

if platform.system() == "Linux":
    #/usr/share/fonts/truetype/unfonts-core/UnDinaru.ttf
    font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
elif platform.system() == "Windows":
    font_path = 'C:/Windows/Fonts/gulim.ttc' #원하는 폰트가 있으면 경로를 바꿔도 됩니다.
elif platform.system() == "Darwin":
    #AppleGothic
    font_path = 'UnDinaru.ttf'
else:
    print("Unknwon OS") # 리눅스, 윈도우, 맥 전부 아닐 경우
    
#os별로 폰트를 가지고 오는 것
    
font_name = font_manager.FontProperties(fname=font_path).get_name() # 위에서 지정한 한글 폰트를 가져오는 코드
rc('font', family=font_name) #한글이 깨지지 않게 한글 폰트를 적용하는것

# %matplotlib inline
#jupyter notebook에서 사용할 수 있도록 설정

# %%
# 각각의 카테고리들과 카테고리별 뉴스 숫자
plt.plot(list(category), category_len) #그래프를 만들어주는 코드

plt.show() #그래프를 보여주는 코드

# %%
plt.bar(list(category), category_len) #막대 그래프 형식으로 나타내기
plt.show()

# %%
df
# Out:
#                                      title  \
# 0            내일 낮 투표소 갈 땐 가볍게 입으세요…아침에는 쌀쌀
# 1                                 사전투표소 설치
# 2                불출마 두 의원이 함께한 여행서 터놓은 속마음
# 3     장애 오빠 돌보러 온 여동생까지…50대 남매 아파트서 화재로 숨져
# 4        함께 술마시던 지인 흉기로 살해 50대 구속…법원 도주 우려
# ...                                    ...
# 3495   영남대 대학기업가센터 지원사업 성과평가 2년 연속 ‘최우수대학’
# 3496                대구·경북 파견 누적 의료인력 3561명
# 3497          MBC 검언유착 녹취록 일부 제출…대검 추가로 내라
# 3498          고용허가제 외국인 노동자 체류기간 50일 일괄 연장
# 3499                              회사가 큰가요?
#
#                                                contents category
# 0     서울·경기·강원 영서 오전 미세먼지 나쁨 제21대 국회의원 선거일이자 수요일인 15...       환경
# 1     제21대 국회의원 선거 사전투표를 하루 앞둔 9일 오후 부산 연제구청 2층 대강당에...       지역
# 2     12일 밤 11시 5분 방송되는 SBS스페셜에서는 제21대 총선 불출마 선언으로 국...       언론
# 3     아파트에서 불이 나 장애가 있는 50대 남성과 돌보러 온 여동생이 함께 숨지는 사고...     사건사고
# 4     함께 술을 마시던 지인을 흉기로 찔러 살해해 긴급체포됐던 50대 남성이 구속됐다. ...     사건사고
# ...                                                 ...      ...
# 3495  영남대가 최근 대학기업가센터 지원사업 성과평가에서 최우수대학에 선정됐다.대학기업가센...       교육
# 3496  대구·경북 파견 누적 의료인력 3561명. 의사 1621명 간호인력 1486명 임상...     사건사고
# 3497  본격 진상조사 앞두고 신경전…채널A 자체조사 마치는대로 제출 채널A와 검사장 간 유...       언론
# 3498  고용허가제 적용을 받는 외국인 노동자의 국내 취업활동기간이 50일 일괄 연장된다. ...       노동
# 3499                                        ⓒ 세상을 보는 눈        교육
#
# [3500 rows x 3 columns]

# %%
df_test = df[df["category"] == "환경"]
# 환경 카테고리의 뉴스들만 가져오는 코드
df_test
# Out:
#                                     title  \
# 0           내일 낮 투표소 갈 땐 가볍게 입으세요…아침에는 쌀쌀
# 7       코로나 확산 막자 충주시 위생업소 5200곳에 출입대장 배부
# 9                 하이원리조트 하늘길에서 노란목도리담비 포착
# 24               중국 이어 국내의 개ㆍ고양이 식용 금지 촉구
# 43            21대 총선날 투표하기 좋은 날씨…전국 맑고 따뜻
# ...                                   ...
# 3474           전국 대체로 맑고 큰 일교차…미세먼지 농도 보통
# 3480                강화 석모도·동검도에 수돗물 공급 개시
# 3485           통영 해양보호구역서 멸종위기종 상괭이 사체 발견
# 3488  경기 서해안 해수서 첫 비브리오패혈증균 검출…작년보다 3주 빨라
# 3490        뉴턴의 사과나무·멘델의 포도나무 국립세종수목원서 본다
#
#                                                contents category
# 0     서울·경기·강원 영서 오전 미세먼지 나쁨 제21대 국회의원 선거일이자 수요일인 15...       환경
# 7     충북 충주시가 신종 코로나바이러스 감염증 확산 방지를 위해 위생업소에 출입대장을 배...       환경
# 9     하이원리조트 하늘길에서 멸종 위기 동물인 노란목도리담비가 포착됐다고 14일 하이원리...       환경
# 24    한국동물보호연합이 6일 오후 서울시청 앞에서 개최한 중국 선전시의 개 고양이 식용금...       환경
# 43    제21대 국회의원 총선거 투표 날인 15일 전국이 대체로 맑고 따뜻할 것으로 예보됐...       환경
# ...                                                 ...      ...
# 3474  수요일인 8일 전국이 대체로 맑은 가운데 강원 동해안에는 오전까지 산발적인 빗방울이...       환경
# 3480  인천시 상수도사업본부는 3일 강화군 삼산면 석모도와 길상면 동검도에 수돗물 공급을 ...       환경
# 3485  해양보호구역인 경남 통영시 용남면 화삼리 장군바위 인근에서 멸종위기종인 상괭이가 낚...       환경
# 3488  경기도가 서해안 바닷물에서 올해 첫 비브리오패혈증균이 검출됐다며 주의를 당부했다.1...       환경
# 3490  뉴턴의 사과나무와 멘델의 포도나무가 국립세종수목원에 식재된다.산림청은 과학적 발견을...       환경
#
# [500 rows x 3 columns]

# %%
texts = ["날씨", "중국", "일교차", "미세먼지", "코로나", "쌀쌀"]
#환경 뉴스에서 우리가 등장 횟수를 알고 싶은 키워드를 지정

texts_lens = []
#준비 하는 것들

for text in texts:
    # 우리가 준비한 키워드들로
    def find_str(contents):
        # 우리가 준비한 키워드들(texts)가 뉴스에 존재하면 return 하기
        if contents.find(text) != -1:
            return True
        else:
            return False

    print(text, len(df_test[df_test["contents"].map(find_str)]))
    # 키워드 내용과 해당 키워드가 있는 뉴스들의 개수
    texts_lens.append(len(df_test[df_test["contents"].map(find_str)]))
# Out:
# 날씨 26
# 중국 28
# 일교차 20
# 미세먼지 120
# 코로나 138
# 쌀쌀 17

# %%
plt.bar(texts, texts_lens)
# x축에 나올 내용, y축에 나올 내용  1대1로 메핑

plt.ylabel('등장한 뉴스의 수') #y축에서 보이는 것
plt.title('환경 등장 키워드') #제목

plt.show() # 그래프 보이게

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hwnau\.conda\envs\cuda\lib\site-packages (1.16.6)

# %%
import numpy as np

# %%
# 다른 카테고리의 뉴스들에서 같은 키워드들이 얼마나 다르게 등장하는지 확인하는 코드 

df_test = df[df["category"] == "노동"]
df_test2 = df[df["category"] == "사건사고"]
# 노동하고 사건사고의 뉴스들만 가져오기

texts = ["코로나", "위기", "구속", "확진"]
# 등장 회수를 볼 키워드들

texts_lens = []
texts_lens2 = []

for text in texts:
    def find_str(contents):
        # 키워드의 존재여부
        if contents.find(text) != -1:
            return True
        else:
            return False

    texts_lens.append(len(df_test[df_test["contents"].map(find_str)]))
    texts_lens2.append(len(df_test2[df_test2["contents"].map(find_str)]))
    # 키워드의 존재 횟수
    
N = len(texts)
# texts의 길 4
X = np.arange(N) 
# 0~3 까지의 값
width = 0.35
# 그래프의 크기

plt.bar(X, texts_lens, width, label='노동')
plt.bar(X + width, texts_lens2, width, label='사건사고')
# 어디에 놓을 것인가, width만큼 띄어주기

plt.ylabel('등장수') #y축 제목
plt.title('환경, 사건사고 비교') #그래프 제목 

plt.xticks(X + width / 2, texts) # 카테고리별로 나눠서 등장시키기 위해서
plt.legend(loc='best') # 범례 쓰기
plt.show()

# %%
X, X + 0.35
# Out:
# (array([0, 1, 2, 3]), array([0.35, 1.35, 2.35, 3.35]))

# %%
category
# Out:
# {'교육', '노동', '사건사고', '식품/의료', '언론', '지역', '환경'}

# %%
df_test = df[df["category"] == "식품/의료"]
df_test2 = df[df["category"] == "사건사고"]
# 노동하고 사건사고의 뉴스들만 가져오기

texts = ["코로나", "안전", "문제"]
# 등장 회수를 볼 키워드들
texts_lens = []
texts_lens2 = []

for text in texts:
    def find_str(contents):
        # 키워드의 존재여부
        if contents.find(text) != -1:
            return True
        else:
            return False

    texts_lens.append(len(df_test[df_test["contents"].map(find_str)]))
    texts_lens2.append(len(df_test2[df_test2["contents"].map(find_str)]))
    # 키워드의 존재 횟수
    
N = len(texts)
# texts의 길 4
X = np.arange(N) 
# 0~3 까지의 값
width = 0.4
# 크기

plt.bar(X, texts_lens, width, label='식품/의료')
plt.bar(X + width, texts_lens2, width, label='사건사고')
# 어디에 놓을 것인가, width만큼 띄어주기

plt.ylabel('등장수')
plt.title('환경, 사건사고 비교')

plt.xticks(X + width / 2, texts)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## 다음 내용

# %%
import nltk
from konlpy.tag import Twitter; t = Twitter()
# Out:
# C:\Users\hwnau\.conda\envs\cuda\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
set(df["category"])
# Out:
# {'교육', '노동', '사건사고', '식품/의료', '언론', '지역', '환경'}

# %%
def test():
    df1= df
    text = list(df1["contents"]) # 우리가 일자리 카테고리만 나오게한 청원 내용 전체를 list로 변경
    text = ' '.join(text) # list로 바뀐 모든 청원 내용을 1개의 문자열로 만들기
    ko_con_text = text # 변수명 번경
    print(len(text)) #길이 확인
    tokens_ko = t.nouns(ko_con_text) # 모든 청원 내용을 형태소 단위로 바꾸는 코드
    tokens_ko
    # 필요없는 것들 제거하는 코드 stop_words = 제거할 형태소를 넣는 리스트
    stop_words = ['각력', '직','제','저', '이','그','때','및','것이','합니다.','\\n',':','','거','수','그' ,"합","이","있는","있습니다.","것","및","하지만","때문에"]

    tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words] 

    #for each_word in tokens_ko:
    #    if each_word not in stop_words:
    #        tokens_ko.append(each_wordword)
    ko = nltk.Text(tokens_ko, name= category+' 청원') #형태소 단위로 나눈 리스트, 이름 지정
    data = ko.vocab().most_common(500) #얼마나 각각의 형태소들이 등장했는지 체크, 상위 500개만 남기고 제거
    tmp_data = dict(data) # 딕셔너리 형태로 바꾸는 코드
    return tmp_data

# %%
test()
# Out:
# 2501162
# {'등': 6145,
#  '코로나': 3506,
#  '명': 3111,
#  '말': 2090,
#  '위해': 1772,
#  '전': 1674,
#  '지역': 1672,
#  '중': 1670,
#  '수업': 1667,
#  '지원': 1628,
#  '씨': 1627,
#  '온라인': 1579,
#  '고': 1560,
#  '후보': 1524,
#  '방송': 1502,
#  '지난': 1459,
#  '선거': 1352,
#  '대한': 1340,
#  '언론': 1329,
#  '고용': 1286,
#  '정부': 1265,
#  '날': 1264,
#  '대해': 1242,
#  '관련': 1239,
#  '학생': 1211,
#  '도': 1165,
#  '사업': 1158,
#  '서울': 1157,
#  '위': 1155,
#  '진행': 1149,
#  '통해': 1137,
#  '이번': 1136,
#  '조사': 1121,
#  '사회': 1106,
#  '상황': 1095,
#  '한국': 1058,
#  '기자': 1050,
#  '확인': 1044,
#  '확': 1042,
#  '검사': 1032,
#  '진자': 1009,
#  '경우': 1006,
#  '격리': 1006,
#  '오전': 996,
#  '신종': 974,
#  '시민': 958,
#  '감염증': 928,
#  '또': 922,
#  '대표': 922,
#  '때문': 916,
#  '개': 912,
#  '코로나바이러스': 906,
#  '보도': 905,
#  '개학': 903,
#  '지난달': 899,
#  '발생': 892,
#  '총선': 879,
#  '로': 879,
#  '관리': 872,
#  '더': 866,
#  '오후': 846,
#  '학교': 844,
#  '결과': 839,
#  '지급': 833,
#  '대상': 826,
#  '생각': 806,
#  '감염': 805,
#  '이후': 796,
#  '사람': 778,
#  '영상': 772,
#  '관계자': 768,
#  '후': 766,
#  '사태': 766,
#  '일': 752,
#  '정보': 751,
#  '채널': 751,
#  '예정': 747,
#  '신청': 737,
#  '확산': 734,
#  '이상': 733,
#  '건': 730,
#  '혐의': 723,
#  '사실': 723,
#  '증가': 720,
#  '활동': 718,
#  '교육': 715,
#  '전국': 713,
#  '를': 713,
#  '계획': 710,
#  '문제': 705,
#  '방역': 703,
#  '곳': 700,
#  '검찰': 693,
#  '센터': 692,
#  '시설': 687,
#  '시작': 685,
#  '교사': 685,
#  '위원회': 684,
#  '기간': 684,
#  '경찰': 683,
#  '뉴스': 683,
#  '안': 681,
#  '내용': 680,
#  '자가': 679,
#  '달': 676,
#  '시': 671,
#  '가장': 666,
#  '노동자': 665,
#  '모두': 663,
#  '환자': 660,
#  '설명': 654,
#  '운영': 654,
#  '지난해': 653,
#  '학년': 644,
#  '사용': 640,
#  '마스크': 638,
#  '뒤': 632,
#  '사진': 623,
#  '재': 621,
#  '주장': 616,
#  '판단': 615,
#  '기준': 613,
#  '발표': 611,
#  '내': 610,
#  '점': 609,
#  '보험': 605,
#  '앞': 603,
#  '대책': 595,
#  '투표': 584,
#  '추가': 579,
#  '격': 578,
#  '우리': 576,
#  '현재': 575,
#  '준비': 571,
#  '결정': 567,
#  '해당': 565,
#  '입국': 565,
#  '분석': 560,
#  '뉴시스': 558,
#  '병원': 552,
#  '현장': 551,
#  '급여': 549,
#  '모든': 548,
#  '라며': 547,
#  '며': 543,
#  '학습': 540,
#  '조치': 530,
#  '본부': 525,
#  '의': 524,
#  '정치': 516,
#  '중앙': 516,
#  '게': 515,
#  '최근': 513,
#  '경제': 511,
#  '마련': 511,
#  '수준': 510,
#  '거리': 510,
#  '차': 510,
#  '대응': 505,
#  '이용': 502,
#  '제공': 498,
#  '교수': 495,
#  '일부': 495,
#  '데': 495,
#  '올해': 494,
#  '민주당': 491,
#  '회': 490,
#  '수사': 490,
#  '국민': 486,
#  '일자리': 484,
#  '사건': 484,
#  '과정': 478,
#  '민언련': 477,
#  '지금': 476,
#  '기업': 476,
#  '다른': 473,
#  '확진': 470,
#  '개표': 470,
#  '평가': 469,
#  '총': 467,
#  '교육부': 465,
#  '참여': 464,
#  '당시': 464,
#  '안전': 463,
#  '정책': 463,
#  '위기': 463,
#  '보고': 462,
#  '세': 461,
#  '해외': 456,
#  '사례': 451,
#  '위반': 450,
#  '임': 448,
#  '업체': 448,
#  '교육청': 447,
#  '국내': 446,
#  '자료': 446,
#  '치료': 443,
#  '신규': 443,
#  '환경': 443,
#  '추진': 442,
#  '기사': 442,
#  '활용': 439,
#  '피해': 438,
#  '적극': 437,
#  '방식': 436,
#  '유지': 431,
#  '가운데': 430,
#  '광주': 430,
#  '다시': 429,
#  '의료': 429,
#  '대학': 429,
#  '번': 426,
#  '콘텐츠': 423,
#  '가능성': 421,
#  '대구': 420,
#  '변경': 416,
#  '층': 412,
#  '물': 412,
#  '당국': 410,
#  '제보': 409,
#  '계속': 407,
#  '주민': 406,
#  '통합': 403,
#  '우려': 403,
#  '앞서': 401,
#  '기록': 400,
#  '판정': 400,
#  '정도': 399,
#  '상태': 397,
#  '두': 395,
#  '지적': 394,
#  '실시': 394,
#  '시험': 394,
#  '선택': 394,
#  '대통령': 392,
#  '영향': 390,
#  '최대': 390,
#  '재판': 389,
#  '부산': 388,
#  '생활': 386,
#  '시행': 385,
#  '의원': 384,
#  '파악': 384,
#  '경기': 383,
#  '처음': 382,
#  '윤': 381,
#  '반영': 380,
#  '포함': 380,
#  '정': 379,
#  '신고': 379,
#  '장관': 378,
#  '직원': 378,
#  '유권자': 378,
#  '접촉': 377,
#  '자신': 377,
#  '시간': 375,
#  '미국': 374,
#  '산업': 371,
#  '취재': 369,
#  '설치': 368,
#  '법': 368,
#  '가지': 367,
#  '못': 366,
#  '감소': 366,
#  '실업': 365,
#  '부': 365,
#  '방': 362,
#  '대비': 362,
#  '주': 360,
#  '강의': 359,
#  '보호': 357,
#  '방안': 355,
#  '이유': 354,
#  '강조': 354,
#  '직접': 352,
#  '긴급': 352,
#  '선': 352,
#  '근로자': 351,
#  '제주': 347,
#  '서비스': 347,
#  '개발': 345,
#  '인천': 341,
#  '시스템': 340,
#  '군': 339,
#  '공개': 337,
#  '미래': 335,
#  '전체': 335,
#  '의혹': 335,
#  '재난': 334,
#  '동안': 333,
#  '비판': 333,
#  '근로': 333,
#  '방법': 331,
#  '시청자': 330,
#  '국가': 329,
#  '인': 329,
#  '취업규칙': 329,
#  '제출': 328,
#  '소득': 328,
#  '여부': 328,
#  '요구': 328,
#  '기관': 327,
#  '입장': 327,
#  '개선': 325,
#  '미세먼지': 324,
#  '초': 323,
#  '시장': 323,
#  '관': 323,
#  '전달': 320,
#  '중이': 318,
#  '기온': 317,
#  '중심': 317,
#  '비': 317,
#  '기존': 316,
#  '세계': 313,
#  '가족': 313,
#  '알': 311,
#  '김': 311,
#  '속': 311,
#  '집': 310,
#  '업무': 309,
#  '적용': 306,
#  '해': 305,
#  '서울시': 305,
#  '연기': 305,
#  '승인': 305,
#  '약': 303,
#  '지속': 303,
#  '처': 299,
#  '각': 298,
#  '가입자': 298,
#  '바': 297,
#  '두기': 297,
#  '회사': 296,
#  '팀': 296,
#  '예상': 293,
#  '다음': 292,
#  '점검': 290,
#  '정당': 289,
#  '별로': 289,
#  '전망': 288,
#  '제작': 288,
#  '중국': 287,
#  '방문': 286,
#  '원': 286,
#  '사고': 285,
#  '요청': 285,
#  '빈': 285,
#  '피해자': 284,
#  '원금': 284,
#  '규모': 284,
#  '역시': 284,
#  '개인': 284,
#  '채용': 283,
#  '예방': 282,
#  '회의': 281,
#  '확대': 279,
#  '단체': 279,
#  '금지': 277,
#  '협의': 275,
#  '절차': 275,
#  '진': 274,
#  '여성': 274,
#  '민주': 274,
#  '역할': 273,
#  '방침': 273,
#  '명의': 272,
#  '확보': 270,
#  '액': 270,
#  '첫': 270,
#  '불': 268,
#  '이하': 267,
#  '한편': 266,
#  '우선': 266,
#  '노력': 266,
#  '공감': 265,
#  '여러분': 263,
#  '경남': 263,
#  '실시간': 263,
#  '전날': 262,
#  '하루': 262,
#  '기자회견': 262,
#  '바이러스': 262,
#  '실제': 261,
#  '중인': 260,
#  '울산': 260,
#  '프로그램': 260,
#  '폭': 260,
#  '진단': 260,
#  '하나': 255,
#  '만큼': 255,
#  '어려움': 255,
#  '다만': 255,
#  '여러': 255,
#  '집중': 255,
#  '의사': 255,
#  '노조': 255,
#  '검토': 254,
#  '평균': 252,
#  '경기도': 252,
#  '보건': 252,
#  '행사': 252,
#  '노총': 252,
#  '구성': 251,
#  '발전': 248,
#  '의견': 248,
#  '년': 248,
#  '최': 246,
#  '기술': 246,
#  '좀': 246,
#  '고등학교': 245,
#  '계약': 245,
#  '부분': 244,
#  '연장': 244,
#  '독자': 243,
#  '볼': 242,
#  '국회의원': 241,
#  '대부분': 241,
#  '인터넷': 241,
#  '차례': 241,
#  '행위': 240,
#  '종합': 240,
#  '거나': 239,
#  '안정': 238,
#  '심사': 238,
#  '아이': 237,
#  '경북': 236,
#  '접속': 236,
#  '개월': 236,
#  '노동': 236,
#  '기기': 236,
#  '접수': 235,
#  '인력': 235,
#  '강원': 234,
#  '자체': 234,
#  '대기': 233,
#  '일정': 233,
#  '법무부': 231,
#  '도움': 231,
#  '각각': 231,
#  '책임': 231,
#  '국회': 229,
#  '구직': 229,
#  '지침': 228,
#  '박사': 228,
#  '분': 228,
#  '특별': 228,
#  '신문': 228,
#  '조선': 228,
#  '주요': 227,
#  '달라': 227,
#  '도로': 226,
#  '복지': 226,
#  '극복': 225,
#  '범죄': 225,
#  '제안': 225,
#  '행정': 225,
#  '불법': 225,
#  '처리': 225,
#  '차량': 224,
#  '지방': 223,
#  '근무': 223,
#  '저희': 223,
#  '여론조사': 222,
#  '방지': 221,
#  '만': 221,
#  '용': 219,
#  '시기': 218,
#  '공유': 218,
#  '고발': 218,
#  '건강': 217,
#  '세월호': 217,
#  '공약': 216,
#  '대한민국': 216,
#  '온': 215,
#  '부장': 215,
#  '회장': 214,
#  '경험': 214,
#  '논의': 214,
#  '출석': 213,
#  '스마트': 213,
#  '비롯': 212,
#  '수가': 212,
#  '비용': 212,
#  '화상': 211,
#  '발언': 211,
#  '유입': 210,
#  '자금': 209,
#  '최소': 209,
#  '영업': 208,
#  '별': 208,
#  '배달': 208,
#  '플랫폼': 208,
#  '발견': 207,
#  '부로': 207,
#  '단': 206,
#  '강화': 206,
#  '동의': 206,
#  '크게': 205,
#  '단계': 205}

# %%
set(df["category"])
# Out:
# {'교육', '노동', '사건사고', '식품/의료', '언론', '지역', '환경'}

# %%
df_test = df[df["category"] == "언론"]
df_test2 = df[df["category"] == "사건사고"]
# 노동하고 사건사고의 뉴스들만 가져오기

texts = ["코로나", "위해", "온라인", '후보', '지난']
# 등장 회수를 볼 키워드들
texts_lens = []
texts_lens2 = []

for text in texts:
    def find_str(contents):
        # 키워드의 존재여부
        if contents.find(text) != -1:
            return True
        else:
            return False

    texts_lens.append(len(df_test[df_test["contents"].map(find_str)]))
    texts_lens2.append(len(df_test2[df_test2["contents"].map(find_str)]))
    # 키워드의 존재 횟수
    
N = len(texts)
# texts의 길 4
X = np.arange(N) 
# 0~3 까지의 값
width = 0.4
# 크기

plt.bar(X, texts_lens, width, label='언론')
plt.bar(X + width, texts_lens2, width, label='사건사고')
# 어디에 놓을 것인가, width만큼 띄어주기

plt.ylabel('등장수')
plt.title('환경, 사건사고 비교')

plt.xticks(X + width / 2, texts)
plt.legend(loc='best')
plt.show()
