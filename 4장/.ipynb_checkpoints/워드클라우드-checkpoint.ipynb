# %%
import matplotlib.pylab as plt
# %matplotlib inline
from wordcloud import WordCloud
import nltk
from konlpy.corpus import kolaw
from konlpy.tag import *
import pandas as pd
import platform
from collections import Counter
from matplotlib import font_manager, rc
from konlpy.tag import Twitter; t = Twitter()
import numpy as np
from PIL import Image
from wordcloud import ImageColorGenerator
import colorsys
import random
import platform
# Out:
# C:\Users\hwnau\.conda\envs\cuda\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
import pandas as pd

# %%
df = pd.read_csv("test_dataset.csv")
df
# Out:
#         num  category  start-days    end-days          person progress  \
# 0    448112       일자리  2018-11-20  2018-12-20     naver - ***   청원진행중
# 1    448111    인권/성평등  2018-11-20  2018-12-20     naver - ***   청원진행중
# 2    448110      농산어촌  2018-11-20  2018-12-20     naver - ***   청원진행중
# 3    448109       일자리  2018-11-20  2018-12-20     naver - ***   청원진행중
# 4    448108    인권/성평등  2018-11-20  2018-12-20     naver - ***   청원진행중
# ..      ...       ...         ...         ...             ...      ...
# 995  446794      보건복지  2018-11-19  2018-12-19     naver - ***   청원진행중
# 996  446793    인권/성평등  2018-11-19  2018-12-19  facebook - ***   청원진행중
# 997  446792        기타  2018-11-19  2018-12-19     naver - ***   청원진행중
# 998  446791     육아/교육  2018-11-19  2018-12-19     naver - ***   청원진행중
# 999  446790  교통/건축/국토  2018-11-19  2018-12-19     naver - ***   청원진행중
#
#                                                  title  count  \
# 0                                         민노총 각력 처벌원한다      1
# 1                의료계의 썩어빠진 뿌리를 자를 수 있는 관련 법규 제정을 해주세요.      2
# 2                                          대전시 동구 -경로당      1
# 3                            정부정책 방향을 전면바꾸는 특단대책 내어놓아야      3
# 4                                        사법농단자들을 탄핵하라!      4
# ..                                                 ...    ...
# 995                                 무료로 치료받고 돌아가는 외국인들     29
# 996  극악한 인권 유린에 대해서는 청소년 보호법을 적용하지 않을 수 있도록 청소년 보호법...     18
# 997     백두칭송위원회를 포함한 진보단체들을 반국가이적행위및 국가보안법위반행위로처벌해야합니다     17
# 998                                               정시확대     17
# 999                                    백해무익한 신주소를 폐지하라      7
#
#                                      petition_overview
# 0    \n민노총 각력 처벌원한다 \n지금 우리 사회에서놀고 있는 청년들을 생긱하면 절대 ...
# 1    \n안녕하세요. \n저희 언니는 올해에 한 대학 병원에 간호사로 입사하였습니다.  ...
# 2    \n안녕하세요. 저는 대전시 동구에 사는 김경락이라 합니다. \n이렇게 소개먼저 하...
# 3    \n정부의 소득주도 최저시급 급상승 정책은 지금경제현실을 직시 재검토해야한다 대통령...
# 4    \n사법농단자들을 탄핵하라! 국민을 노예로 개돼지로 보기때문이다.   \n정의란 무...
# ..                                                 ...
# 995  \n결핵 걸린 채 한국에 와서 0원으로 치료받고 돌아가는 \n\n중국인, 베트남인,...
# 996  \n인권을 유린한 것에 대한 대가는 인간의 존엄성을 유린당하는 것 이외에는 없습니다...
# 997  \n백두칭송위원회들은 서울한복판과 광화문에서 김정은 찬양하고 미화하는 행동을 하는 ...
# 998  \n옛날 선생님들 열약한 근무환경과 급여수준이었으나, 이제는 노후 보장된 대표적 안...
# 999  \n시행된지 십여년이 지나고 엄청난 예산을 쏟았지만 아직도 문제가 많은 신주소체계를...
#
# [1000 rows x 9 columns]

# %%
set(df["category"])
# Out:
# {'경제민주화',
#  '교통/건축/국토',
#  '기타',
#  '농산어촌',
#  '문화/예술/체육/언론',
#  '미래',
#  '반려동물',
#  '보건복지',
#  '성장동력',
#  '안전/환경',
#  '외교/통일/국방',
#  '육아/교육',
#  '인권/성평등',
#  '일자리',
#  '저출산/고령화대책',
#  '정치개혁',
#  '행정'}

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)
    
def make_cloud(category, png_name=0,state="no", background_color_n='white', max_font_size_n = 40):
        
    df1= (df[df["category"]==category])

    text = list(df1["petition_overview"])
    text = ' '.join(text)
    
    ko_con_text = text
    print(len(text))
    #print(text)
    tokens_ko = t.nouns(ko_con_text)
    print("ok")
    stop_words = ['직','제','저', '이','그','때','및','것이','합니다.','\\n',':','','거','수','그' ,"합","이","있는","있습니다.","것","및","하지만","때문에"]
    tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

    text = ' '.join(tokens_ko)
    #text
    #f = open(category+".txt", 'w')
    #f.write(text)
    #f.close()

    ko = nltk.Text(tokens_ko, name= category+' 청원')
    
    if platform.system() == 'Darwin': 
        font_url = "/Library/Fonts/AppleGothic.ttf"
        rc('font', family='AppleGothic')
        #Mac pc의 경우
    elif platform.system() == 'Windows': 
        font_url = 'C:/Windows/Fonts/malgun.ttf'
        font_name = font_manager.FontProperties(fname=font_url).get_name()
        rc('font', family=font_name)
    elif platform.system() == 'Linux': 
        font_url = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
        font_name = font_manager.FontProperties(fname=font_url).get_name()
        rc('font', family=font_name)

    # %matplotlib inline

    data = ko.vocab().most_common(500)
    tmp_data = dict(data)

    if(png_name):
        korea = np.array(Image.open("img/"+png_name))
    else:
        korea = np.array(Image.open("img/"+category+"1.png"))
    
    image_colors = ImageColorGenerator(korea)
    
    
    wordcloud = WordCloud(font_path=font_url,
                         relative_scaling = 0.2, mask=korea,
                         background_color=background_color_n,
                          min_font_size=1, max_font_size=max_font_size_n
                         ).generate_from_frequencies(tmp_data)
    plt.figure(figsize=(30,30))
    
    #설정에 맞게 색깔 변경
    if state == "no":
        plt.imshow(wordcloud)
    elif state == "img":
        plt.imshow(wordcloud.recolor(color_func=image_colors) ,interpolation='bilinear')
    elif state == "grey":
        plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3) ,interpolation='bilinear')
    else:
        plt.imshow(wordcloud.recolor(color_func=lambda *args, **kwargs: state, random_state=3) ,interpolation='bilinear')
    
    plt.axis("off")
    plt.show()

# %%
make_cloud("일자리", "일자리.png",state="img", background_color_n='white', max_font_size_n = 100)
# Out:
# 61513
# ok

# %% [markdown]
# https://pixabay.com/ko/illustrations/%EB%82%A8%EC%9E%90-%EC%84%B1%EC%9D%B8-%EC%82%AC%EC%97%85%EA%B0%80-%EB%85%B8%ED%8A%B8%EB%B6%81-1459246/

# %%
category = "일자리"

df1= (df[df["category"]==category])

text = list(df1["petition_overview"])
text = ' '.join(text)

ko_con_text = text
print(len(text))
#print(text)
tokens_ko = t.nouns(ko_con_text)
print("ok")
stop_words = ['직','제','저', '이','그','때','및','것이','합니다.','\\n',':','','거','수','그' ,"합","이","있는","있습니다.","것","및","하지만","때문에"]
tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

text = ' '.join(tokens_ko)
#text
#f = open(category+".txt", 'w')
#f.write(text)
#f.close()

ko = nltk.Text(tokens_ko, name= category+' 청원')
# Out:
# 61513
# ok

# %%
tokens_ko
# Out:
# ['민노총',
#  '각력',
#  '처벌',
#  '지금',
#  '우리',
#  '사회',
#  '청년',
#  '생긱하',
#  '절대',
#  '총파업',
#  '못할겄',
#  '민노총',
#  '이자',
#  '밥그릇',
#  '생각',
#  '양심',
#  '인간',
#  '법',
#  '허용',
#  '범위',
#  '강력',
#  '처벌',
#  '이자',
#  '절대',
#  '사회',
#  '약자',
#  '정부',
#  '소득',
#  '주도',
#  '최저',
#  '시급',
#  '급상승',
#  '정책',
#  '지금',
#  '경제',
#  '현실',
#  '직시',
#  '재',
#  '검토',
#  '대통령',
#  '지지율',
#  '추락',
#  '요인',
#  '서민',
#  '일자리',
#  '구',
#  '경기',
#  '불황',
#  '현실',
#  '최저',
#  '시급',
#  '급상승',
#  '더',
#  '자영',
#  '업자',
#  '고통',
#  '가중',
#  '현실',
#  '내년',
#  '불황',
#  '최저',
#  '시급',
#  '이상',
#  '계획',
#  '경비원',
#  '판매원',
#  '청소원',
#  '서비스',
#  '업종',
#  '등',
#  '취약',
#  '계층',
#  '일자리',
#  '더욱',
#  '일자리',
#  '구',
#  '더',
#  '자영',
#  '업자',
#  '고통',
#  '더',
#  '가중',
#  '정부',
#  '특단',
#  '정책',
#  '삼성',
#  '전자',
#  '운전기사',
#  '최근',
#  '언론',
#  '보도',
#  '삼성',
#  '운전기사',
#  '무기',
#  '직전',
#  '환의',
#  '실상',
#  '글',
#  '언론',
#  '선의',
#  '고용',
#  '사실',
#  '파견',
#  '근무',
#  '삼성',
#  '근무',
#  '사람',
#  '고소',
#  '문제',
#  '제기로',
#  '법적',
#  '문제',
#  '인원',
#  '채용',
#  '나머지',
#  '미만',
#  '무자',
#  '언론',
#  '파견',
#  '기간',
#  '만료',
#  '후',
#  '순차',
#  '채용',
#  '보도',
#  '실상',
#  '만료',
#  '시',
#  '퇴직',
#  '언론',
#  '마치',
#  '정부',
#  '일자리',
#  '정책',
#  '호응',
#  '듯이',
#  '선심',
#  '보도',
#  '나머지',
#  '파견',
#  '무자',
#  '희롱',
#  '원통',
#  '동아일보',
#  '김지현',
#  '기자',
#  '기사',
#  '등',
#  '신문사',
#  '기사',
#  '파견',
#  '만료',
#  '시',
#  '순차',
#  '채용',
#  '보도',
#  '희망',
#  '가지',
#  '근무',
#  '기사',
#  '말',
#  '언론',
#  '채용',
#  '뒤',
#  '해고',
#  '삼성',
#  '회사',
#  '이미지',
#  '위해',
#  '파견',
#  '기사',
#  '가족',
#  '감정',
#  '건가',
#  '친구',
#  '보',
#  '누구',
#  '열',
#  '순경',
#  '셤',
#  '공부',
#  '한번',
#  '중소기업',
#  '재직',
#  '청년',
#  '대기업',
#  '중소기업',
#  '근로계약서',
#  '연장',
#  '로시',
#  '특근',
#  '비지',
#  '급등',
#  '연봉',
#  '포함',
#  '연월',
#  '차',
#  '또한',
#  '마찬가지',
#  '월급',
#  '포함',
#  '이유',
#  '서류',
#  '작업',
#  '출근',
#  '퇴근',
#  '정시',
#  '악한',
#  '상황',
#  '처',
#  '근로자',
#  '일자리',
#  '구',
#  '내부',
#  '고발',
#  '노동부',
#  '진정',
#  '상공',
#  '안해',
#  '회사',
#  '불이익',
#  '아무',
#  '용기',
#  '못내',
#  '사장',
#  '직접',
#  '면담',
#  '해소',
#  '더',
#  '더욱',
#  '연월',
#  '차도',
#  '윗사람',
#  '퇴근',
#  '문화',
#  '때문',
#  '살기',
#  '노동부',
#  '고용노동부',
#  '정부',
#  '문제',
#  '해결',
#  '노동자',
#  '문제',
#  '해결',
#  '좀',
#  '직접',
#  '업체',
#  '별',
#  '점검',
#  '업체',
#  '강력',
#  '처벌',
#  '사실',
#  '문제',
#  '사람',
#  '고통',
#  '업체',
#  '대한',
#  '타격',
#  '알',
#  '나라',
#  '워',
#  '밸',
#  '급여',
#  '연월',
#  '차',
#  '등등',
#  '업체',
#  '불',
#  '행시',
#  '강력',
#  '처벌',
#  '요구',
#  '바',
#  '광주',
#  '광역시',
#  '인건비',
#  '지원',
#  '사업',
#  '통해',
#  '선발',
#  '직원',
#  '신입',
#  '직원',
#  '직무',
#  '교육',
#  '지난',
#  '박',
#  '교육',
#  '교육',
#  '내용',
#  '창업',
#  '하라',
#  '내용',
#  '지난',
#  '윤장현',
#  '시장',
#  '광주시',
#  '공무원',
#  '저런',
#  '강연',
#  '창업',
#  '대표자',
#  '신입사원',
#  '직무',
#  '교육',
#  '창업',
#  '하라',
#  '교육',
#  '직원',
#  '회사',
#  '소리',
#  '광주',
#  '광역시',
#  '인건비',
#  '지원',
#  '박',
#  '겨자',
#  '먹기',
#  '직원',
#  '창업',
#  '창업',
#  '교육',
#  '광주',
#  '광역시',
#  '공무원',
#  '지난',
#  '인건비',
#  '사업',
#  '실제',
#  '직원',
#  '일',
#  '실사',
#  '한번',
#  '실사',
#  '미리',
#  '연락',
#  '세금',
#  '얼마나',
#  '척',
#  '작년',
#  '대통령',
#  '선전',
#  '기껏',
#  '인건비',
#  '지원',
#  '고용',
#  '사원',
#  '창업',
#  '교육',
#  '세금',
#  '줄줄',
#  '세고',
#  '일자리',
#  '창',
#  '주',
#  '밤',
#  '삶',
#  '아내',
#  '딸아이',
#  '아빠',
#  '주',
#  '월급',
#  '충당',
#  '일',
#  '대리',
#  '물류',
#  '창고',
#  '알바',
#  '밤',
#  '삶',
#  '일자리',
#  '창',
#  '출입',
#  '진짜',
#  '일자리',
#  '격의',
#  '료',
#  '왜',
#  '포기',
#  '의사',
#  '협회',
#  '파업',
#  '의사',
#  '협회',
#  '최고',
#  '부의',
#  '상징',
#  '의사',
#  '막강',
#  '가요',
#  '의료',
#  '관련',
#  '중소기업',
#  '활성화',
#  '이상',
#  '의료',
#  '혜택',
#  '격의',
#  '료',
#  '왜',
#  '포기',
#  '하강',
#  '취업',
#  '자영',
#  '업자',
#  '폐업',
#  '무엇',
#  '더',
#  '취업',
#  '신경',
#  '대리',
#  '수술',
#  '환자',
#  '사망',
#  '의사',
#  '기존',
#  '기득권',
#  '자',
#  '집단',
#  '이기주의',
#  '격의',
#  '료',
#  '무조건',
#  '반대',
#  '외치',
#  '경기',
#  '하강',
#  '원인',
#  '대두',
#  '겁',
#  '기존',
#  '의사',
#  '이기주의',
#  '편승',
#  '의사',
#  '병원',
#  '이제',
#  '경쟁',
#  '시대',
#  '환자',
#  '중심',
#  '의료',
#  '정책',
#  '전면',
#  '격의',
#  '료',
#  '시행',
#  '경기',
#  '음주운전',
#  '말리',
#  '사람',
#  '방조',
#  '죄',
#  '처벌',
#  '윤창',
#  '호법',
#  '국무회의',
#  '조속',
#  '통과',
#  '희망',
#  '국민',
#  '눈',
#  '최근',
#  '음주운전',
#  '또',
#  '사망',
#  '사람',
#  '이용주',
#  '의원',
#  '문제',
#  '최근',
#  '또',
#  '음주운전',
#  '사망',
#  '사람',
#  '윤창',
#  '호법',
#  '조속',
#  '통과',
#  '경찰',
#  '처리',
#  '더욱',
#  '강화',
#  '필요',
#  '최근',
#  '사망',
#  '사고',
#  '생기',
#  '음주운전',
#  '윤창',
#  '호법',
#  '통과',
#  '청와대',
#  '국민',
#  '눈높이',
#  '윤창',
#  '호법',
#  '조속',
#  '국무회의',
#  '통과',
#  '국회',
#  '엉망',
#  '최근',
#  '정치권',
#  '일자리',
#  '창',
#  '입',
#  '발린',
#  '얘기',
#  '시장',
#  '일',
#  '사람',
#  '사람',
#  '구',
#  '중소기업',
#  '왜',
#  '현상',
#  '이유',
#  '국가',
#  '사업',
#  '추진',
#  '분',
#  '파악',
#  '중소기업',
#  '취업',
#  '면',
#  '대기업',
#  '공무원',
#  '비교',
#  '대기업',
#  '급여',
#  '대부분',
#  '환경',
#  '근무',
#  '경우',
#  '대기업',
#  '하청',
#  '등',
#  '환경',
#  '자생',
#  '중소기업',
#  '과연',
#  '자신',
#  '은퇴',
#  '존재',
#  '의문',
#  '안정',
#  '근무',
#  '신체',
#  '장애',
#  '발생',
#  '시',
#  '대부분',
#  '퇴사',
#  '여건',
#  '요즈음',
#  '청년',
#  '무조건',
#  '공무원',
#  '대기업',
#  '우선',
#  '직장',
#  '구',
#  '중소기업',
#  '보지',
#  '해결',
#  '방안',
#  '제안',
#  '톼사',
#  '은퇴',
#  '대기업',
#  '국민연금',
#  '더',
#  '수령',
#  '책',
#  '마련',
#  '비록',
#  '근무',
#  '환경',
#  '근무',
#  '은퇴',
#  '후',
#  '대기업',
#  '더',
#  '나은',
#  '생활',
#  '희망이',
#  '중소기업',
#  '근무',
#  '욕심',
#  '생각',
#  '중소기업',
#  '근로자',
#  '추가',
#  '혜택',
#  '부여',
#  '급여',
#  '비록',
#  '대기업',
#  '한번',
#  '더',
#  '세제',
#  '혜택',
#  '조금',
#  '더',
#  '자긍심',
#  '고취',
#  '생각',
#  '중소기업',
#  '근무',
#  '장애',
#  '발생',
#  '시',
#  '회사',
#  '계속',
#  '국가',
#  '잭',
#  '마련',
#  '평생',
#  '직장',
#  '생산',
#  '사원',
#  '장애',
#  '직종',
#  '변경',
#  '생산',
#  '판매',
#  '시',
#  '기업',
#  '근무',
#  '환경',
#  '원금',
#  '책정',
#  '정책',
#  '중소기업',
#  '종신직',
#  '취업',
#  '의지',
#  '주변',
#  '중소기업',
#  '대표',
#  '실제',
#  '학교',
#  '등',
#  '직원',
#  '요청',
#  '면',
#  '취업',
#  '의사',
#  '일자리',
#  '취업',
#  '안',
#  '대부분',
#  '중소기업',
#  '취업',
#  '사회',
#  '복지',
#  '퇴사',
#  '후',
#  '대기업',
#  '복지',
#  '혜택',
#  '정책',
#  '청년',
#  '취업',
#  '바른길',
#  '생각',
#  '청원',
#  '글',
#  '장애인',
#  '사회',
#  '약자',
#  '대통령',
#  '여사',
#  '관심',
#  '사항',
#  '중',
#  '한가지',
#  '장애인',
#  '취업',
#  '취업',
#  '자리',
#  '유지',
#  '사항',
#  '따라서',
#  '장애인',
#  '고용',
#  '유지',
#  '위',
#  '지원',
#  '혜택',
#  '취업',
#  '장애인',
#  '일자리',
#  '유지',
#  '위',
#  '현재',
#  '장애인',
#  '고용',
#  '기업체',
#  '사업',
#  '유지',
#  '무엇',
#  '생각',
#  '현재',
#  '법',
#  '장애인',
#  '사업',
#  '장애인',
#  '표준',
#  '사업',
#  '등',
#  '장애인',
#  '고용',
#  '생산',
#  '제품',
#  '대해',
#  '공공기관',
#  '우선',
#  '구매',
#  '법',
#  '정',
#  '현실',
#  '우선',
#  '구매',
#  '일반',
#  '사업자',
#  '동등',
#  '구매',
#  '형태',
#  '보이',
#  '우선',
#  '구매',
#  '제도',
#  '사실',
#  '공공기관',
#  '제도로',
#  '전략',
#  '장애인',
#  '고용',
#  '촉진',
#  '유지',
#  '일반인',
#  '우선',
#  '보호',
#  '따라서',
#  '현재',
#  '법률',
#  '지정',
#  '장애인',
#  '우선',
#  '제도',
#  '선택',
#  '강제',
#  '부여',
#  '공공기관',
#  '예산',
#  '지출',
#  '시',
#  '장애',
#  '사회',
#  '약자',
#  '위',
#  '구매',
#  '질',
#  '경우',
#  '각종',
#  '평가',
#  '통',
#  '실천',
#  '공무원',
#  '공로상',
#  '기관',
#  '우수',
#  '평가',
#  '다음',
#  '예산',
#  '보너스',
#  '예산',
#  '예산',
#  '우선',
#  '배정',
#  '등',
#  '혜택',
#  '부여',
#  '다수',
#  '공공기관',
#  '장애인',
#  '사회',
#  '약자',
#  '위해',
#  '솔선수범',
#  '방법',
#  '스스로',
#  '모색',
#  '대통령',
#  '관심',
#  '시기',
#  '우리',
#  '지금',
#  '외국인',
#  '최저임금',
#  '적용',
#  '국회',
#  '특별법',
#  '외국인',
#  '전용',
#  '단지',
#  '최저임금',
#  '적용',
#  '지역',
#  '국내',
#  '기업',
#  '외국',
#  '기업',
#  '투자',
#  '기업',
#  '외국인',
#  '한국인',
#  '필요',
#  '한국인',
#  '자기',
#  '연봉',
#  '취업',
#  '개',
#  '고용',
#  '증진',
#  '국민',
#  '총',
#  '생산',
#  '증가',
#  '외국인',
#  '근로자',
#  '별도',
#  '비자',
#  '비용',
#  '음으로',
#  '세수',
#  '증가',
#  '유발',
#  '업종',
#  '기업',
#  '운영',
#  '업주',
#  '곳',
#  '이전',
#  '위해',
#  '인프라',
#  '외국인',
#  '통제',
#  '불법',
#  '취업',
#  '막',
#  '외국',
#  '우리나라',
#  '불법',
#  '취업',
#  '생각',
#  '취업',
#  '비자',
#  '관리',
#  '우리',
#  '부정',
#  '출발',
#  '전국',
#  '불법',
#  '취업',
#  '정부',
#  '통뎨',
#  '선화',
#  '위해',
#  '외국인',
#  '전용',
#  '제조업',
#  '단지',
#  '양성화',
#  '업종',
#  '인력',
#  '난도',
#  '한국인',
#  '절대로',
#  '업종',
#  '취업',
#  '음',
#  '현재',
#  '변호사',
#  '의사',
#  '회계사',
#  '세무사',
#  '건축사',
#  '등',
#  '자격증',
#  '평생',
#  '나이',
#  '신체',
#  '정신',
#  '간판',
#  '명의',
#  '용돈',
#  '경우',
#  '한번',
#  '자격증',
#  '평생',
#  '현',
#  '제도',
#  '대해',
#  '아래',
#  '변호사',
#  '등',
#  '전문',
#  '자격증',
#  '유효',
#  '기간',
#  '나이',
#  '세로',
#  '제한',
#  '세',
#  '자격증',
#  '반납',
#  '세',
#  '이후',
#  '다시',
#  '시험',
#  '합당',
#  '신체',
#  '정신',
#  '자격',
#  '검증',
#  '세',
#  '이후',
#  '시험',
#  '향후',
#  '자격증',
#  '시험',
#  '합격자',
#  '자격증',
#  '유효',
#  '기간',
#  '연령',
#  '기재',
#  '교부',
#  '뿐',
#  '현재',
#  '자격증',
#  '보유',
#  '대해',
#  '서도',
#  '세',
#  '이후',
#  '시험',
#  '방향',
#  '젊은이',
#  '일',
#  '젊은이',
#  '자격증',
#  '일',
#  '기회',
#  '마련',
#  '지금',
#  '정부',
#  '일자리',
#  '떄문',
#  '머리',
#  '답',
#  '생각',
#  '답',
#  '첫째',
#  '실업',
#  '급여',
#  '둘째',
#  '실업',
#  '급여',
#  '실업',
#  '급여',
#  '백',
#  '도',
#  '실업',
#  '급여',
#  '폐지',
#  '완전',
#  '폐지',
#  '개월',
#  '도나',
#  '취업',
#  '자리',
#  '직원',
#  '채용',
#  '대부분',
#  '사람',
#  '실업',
#  '급여',
#  '일',
#  '조건',
#  '보험',
#  '미가',
#  '입',
#  '급여',
#  '통장',
#  ...]

# %%
data = ko.vocab().most_common(500)
tmp_data = dict(data)

tmp_data
# Out:
# {'무궁화': 96,
#  '일': 74,
#  '일자리': 73,
#  '등': 67,
#  '사람': 63,
#  '생각': 62,
#  '청년': 60,
#  '회사': 54,
#  '더': 52,
#  '노인': 47,
#  '언니': 45,
#  '정부': 43,
#  '문제': 43,
#  '국민': 43,
#  '고용': 41,
#  '근무': 41,
#  '지원': 41,
#  '취업': 40,
#  '계약': 39,
#  '정규직': 38,
#  '말': 37,
#  '관리': 37,
#  '비정규직': 36,
#  '사회': 35,
#  '채용': 33,
#  '다이소': 33,
#  '업체': 32,
#  '지금': 31,
#  '나라': 31,
#  '정책': 30,
#  '국가': 30,
#  '장애인': 30,
#  '남산': 30,
#  '꽃': 30,
#  '운영': 28,
#  '경우': 27,
#  '세': 27,
#  '장': 27,
#  '근로자': 26,
#  '공공기관': 26,
#  '씨': 26,
#  '기간': 25,
#  '위해': 25,
#  '사업': 25,
#  '안': 25,
#  '위': 25,
#  '우리': 24,
#  '직원': 24,
#  '기업': 24,
#  '한국': 24,
#  '의': 24,
#  '내용': 23,
#  '시험': 23,
#  '개월': 23,
#  '전환': 23,
#  '무기계약직': 23,
#  '대통령': 22,
#  '희망': 22,
#  '때문': 22,
#  '창': 22,
#  '중': 22,
#  '돈': 22,
#  '명': 22,
#  '경제': 21,
#  '급여': 21,
#  '직업': 21,
#  '만': 21,
#  '이유': 20,
#  '교육': 20,
#  '곳': 20,
#  '시간': 20,
#  '점': 20,
#  '서류': 19,
#  '대한': 19,
#  '왜': 19,
#  '관련': 19,
#  '현재': 19,
#  '대해': 19,
#  '사용': 19,
#  '이행': 19,
#  '인원': 18,
#  '또한': 18,
#  '지역': 18,
#  '나이': 18,
#  '조사': 18,
#  '가장': 18,
#  '입사': 18,
#  '종로': 18,
#  '각서': 18,
#  '법': 17,
#  '대기업': 17,
#  '노동자': 17,
#  '개': 17,
#  '뿐': 17,
#  '업무': 17,
#  '정말': 17,
#  '저희': 17,
#  '서울': 17,
#  '이상': 16,
#  '서비스': 16,
#  '중소기업': 16,
#  '하루': 16,
#  '각': 16,
#  '다른': 16,
#  '급행열차': 16,
#  '스쿨': 16,
#  '가로수': 16,
#  '면접': 16,
#  '언론': 15,
#  '파견': 15,
#  '기사': 15,
#  '가지': 15,
#  '공무원': 15,
#  '대부분': 15,
#  '직장': 15,
#  '하나': 15,
#  '세습': 15,
#  '내': 15,
#  '고': 15,
#  '정도': 15,
#  '어르신': 15,
#  '시': 14,
#  '문화': 14,
#  '해결': 14,
#  '통해': 14,
#  '자': 14,
#  '시행': 14,
#  '마련': 14,
#  '불법': 14,
#  '우리나라': 14,
#  '실업': 14,
#  '문재인': 14,
#  '시민': 14,
#  '준비': 14,
#  '노력': 14,
#  '현실': 13,
#  '후': 13,
#  '알': 13,
#  '지난': 13,
#  '혜택': 13,
#  '분': 13,
#  '청원': 13,
#  '사항': 13,
#  '못': 13,
#  '공개': 13,
#  '보장': 13,
#  '모두': 13,
#  '안양천': 13,
#  '애국심': 13,
#  '나라꽃': 13,
#  '비프': 13,
#  '렌': 13,
#  '계획': 12,
#  '최근': 12,
#  '무기': 12,
#  '주': 12,
#  '활성화': 12,
#  '이제': 12,
#  '계속': 12,
#  '제도': 12,
#  '기회': 12,
#  '해': 12,
#  '개발': 12,
#  '대한민국': 12,
#  '인생': 12,
#  '조성': 12,
#  '의자': 12,
#  '매장': 12,
#  '절대': 11,
#  '뒤': 11,
#  '월급': 11,
#  '또': 11,
#  '우선': 11,
#  '판매': 11,
#  '복지': 11,
#  '시기': 11,
#  '외국인': 11,
#  '투자': 11,
#  '막': 11,
#  '전국': 11,
#  '제한': 11,
#  '미래': 11,
#  '본인': 11,
#  '인': 11,
#  '대상': 11,
#  '날': 11,
#  '비': 11,
#  '행동': 11,
#  '오히려': 11,
#  '축제': 11,
#  '안전': 11,
#  '근로': 11,
#  '전문학교': 11,
#  '재': 10,
#  '글': 10,
#  '사실': 10,
#  '공부': 10,
#  '재직': 10,
#  '근로계약서': 10,
#  '좀': 10,
#  '경쟁': 10,
#  '통과': 10,
#  '국회': 10,
#  '방안': 10,
#  '조금': 10,
#  '예산': 10,
#  '자기': 10,
#  '젊은이': 10,
#  '도': 10,
#  '마음': 10,
#  '시작': 10,
#  '년': 10,
#  '필기': 10,
#  '지자체': 10,
#  '무대': 10,
#  '행위': 10,
#  '번': 10,
#  '노동': 10,
#  '호소': 10,
#  '시급': 9,
#  '서민': 9,
#  '보도': 9,
#  '요구': 9,
#  '창업': 9,
#  '세금': 9,
#  '의사': 9,
#  '생활': 9,
#  '유지': 9,
#  '인력': 9,
#  '자격증': 9,
#  '다시': 9,
#  '방향': 9,
#  '조건': 9,
#  '쪽': 9,
#  '전': 9,
#  '모든': 9,
#  '정보': 9,
#  '도움': 9,
#  '통계': 9,
#  '이용': 9,
#  '정년': 9,
#  '기준': 9,
#  '차별': 9,
#  '관': 9,
#  '효과': 9,
#  '공원': 9,
#  '활용': 9,
#  '단': 9,
#  '책임': 9,
#  '제대로': 9,
#  '진행': 9,
#  '대우': 9,
#  '세계': 9,
#  '수립': 9,
#  '권리': 9,
#  '동의': 9,
#  '본사': 9,
#  '특별': 9,
#  '처벌': 8,
#  '업종': 8,
#  '더욱': 8,
#  '삼성': 8,
#  '누구': 8,
#  '한번': 8,
#  '차': 8,
#  '상황': 8,
#  '사원': 8,
#  '기존': 8,
#  '시대': 8,
#  '자신': 8,
#  '제안': 8,
#  '부여': 8,
#  '구매': 8,
#  '기관': 8,
#  '이후': 8,
#  '나': 8,
#  '게': 8,
#  '프로그램': 8,
#  '개인': 8,
#  '해당': 8,
#  '상담': 8,
#  '걸': 8,
#  '납부': 8,
#  '의무': 8,
#  '노후': 8,
#  '공제': 8,
#  '가능': 8,
#  '누가': 8,
#  '근거': 8,
#  '광장': 8,
#  '지급': 8,
#  '설립': 8,
#  '백만원': 8,
#  '백성': 8,
#  '노출': 8,
#  '주장': 8,
#  '미세먼지': 8,
#  '행각': 8,
#  '한겨레': 8,
#  '아르바이트': 8,
#  '최종': 8,
#  '주휴수당': 8,
#  '만료': 7,
#  '연봉': 7,
#  '포함': 7,
#  '사장': 7,
#  '실제': 7,
#  '삶': 7,
#  '무조건': 7,
#  '의원': 7,
#  '환경': 7,
#  '하청': 7,
#  '발생': 7,
#  '자리': 7,
#  '방법': 7,
#  '비용': 7,
#  '정신': 7,
#  '기재': 7,
#  '민주당': 7,
#  '전혀': 7,
#  '즉': 7,
#  '특허': 7,
#  '구청': 7,
#  '피해': 7,
#  '월': 7,
#  '비리': 7,
#  '결혼': 7,
#  '가격': 7,
#  '로': 7,
#  '임금': 7,
#  '동안': 7,
#  '보고': 7,
#  '내일': 7,
#  '고령': 7,
#  '종합': 7,
#  '여기': 7,
#  '재계약': 7,
#  '결과': 7,
#  '심기': 7,
#  '관광': 7,
#  '산림청': 7,
#  '회': 7,
#  '사랑': 7,
#  '관광객': 7,
#  '시니어': 7,
#  '백범': 7,
#  '둘레길': 7,
#  '상설': 7,
#  '발언': 7,
#  '시설': 7,
#  '지점': 7,
#  '를': 7,
#  '단체': 7,
#  '힘': 7,
#  '독과점': 7,
#  '회장': 7,
#  '첨부': 7,
#  '종료': 7,
#  '화재': 7,
#  '약자': 6,
#  '최저': 6,
#  '퇴직': 6,
#  '친구': 6,
#  '연장': 6,
#  '내부': 6,
#  '직접': 6,
#  '바': 6,
#  '시장': 6,
#  '료': 6,
#  '최고': 6,
#  '반대': 6,
#  '청와대': 6,
#  '장애': 6,
#  '퇴사': 6,
#  '고취': 6,
#  '생산': 6,
#  '정': 6,
#  '법률': 6,
#  '강제': 6,
#  '평가': 6,
#  '최저임금': 6,
#  '한국인': 6,
#  '총': 6,
#  '현': 6,
#  '변화': 6,
#  '발전': 6,
#  '행정기관': 6,
#  '제공': 6,
#  '뭘': 6,
#  '해도': 6,
#  '문의': 6,
#  '단속': 6,
#  '집행유예': 6,
#  '선수': 6,
#  '수준': 6,
#  '식': 6,
#  '무시': 6,
#  '효율': 6,
#  '처음': 6,
#  '이하': 6,
#  '군복무': 6,
#  '아침': 6,
#  '일조': 6,
#  '소외': 6,
#  '서울시': 6,
#  '복': 6,
#  '제발': 6,
#  '단계': 6,
#  '산업': 6,
#  '길': 6,
#  '푸드': 6,
#  '트럭': 6,
#  '매일': 6,
#  '청소': 6,
#  '학원': 6,
#  '선': 6,
#  '술': 6,
#  '매우': 6,
#  '실태': 6,
#  '센터': 6,
#  '당장': 6,
#  '무궁화나무': 6,
#  '의미': 6,
#  '함': 6,
#  '대하': 6,
#  '항': 6,
#  '상위': 6,
#  '여러가지': 6,
#  '불만': 6,
#  '이해': 6,
#  '적폐': 6,
#  '우체국': 6,
#  '비치': 6,
#  '복종': 6,
#  '작성': 6,
#  '출장': 6,
#  '발령': 6,
#  '인사': 6,
#  '망': 6,
#  '입장': 6,
#  '여당': 6,
#  '지지율': 5,
#  '구': 5,
#  '고통': 5,
#  '법적': 5,
#  '나머지': 5,
#  '노동부': 5,
#  '등등': 5,
#  '불': 5,
#  '광주': 5,
#  '인건비': 5,
#  '직무': 5,
#  '포기': 5,
#  '무엇': 5,
#  '사망': 5,
#  '집단': 5,
#  '중심': 5,
#  '음주운전': 5,
#  '윤창': 5,
#  '호법': 5,
#  '국무회의': 5,
#  '눈': 5,
#  '필요': 5,
#  '추진': 5,
#  '파악': 5,
#  '은퇴': 5,
#  '희망이': 5,
#  '자긍심': 5,
#  '대표': 5,
#  '학교': 5,
#  '따라서': 5,
#  '일반': 5,
#  '일반인': 5,
#  '각종': 5,
#  '모색': 5,
#  '증진': 5,
#  '별도': 5,
#  '용돈': 5,
#  '연령': 5,
#  '답': 5,
#  '둘째': 5,
#  '백': 5,
#  '세력': 5,
#  '행정': 5,
#  '인구': 5,
#  '도시': 5,
#  '끝': 5,
#  '평화': 5,
#  '국정조사': 5,
#  '요즘': 5,
#  '세상': 5,
#  '아이디어': 5,
#  '부담': 5,
#  '조선족': 5,
#  '관할': 5,
#  '전체': 5,
#  '심지어': 5,
#  '국민은행': 5,
#  '로부터': 5,
#  '연금': 5}

# %%
png_name = "일자리.png"
background_color_n = "white"
max_font_size_n = 100
state = "img"

if platform.system() == 'Darwin': 
    font_url = "/Library/Fonts/AppleGothic.ttf"
    rc('font', family='AppleGothic')
    #Mac pc의 경우
elif platform.system() == 'Windows': 
    font_url = 'C:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=font_url).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Linux': 
    font_url = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
    font_name = font_manager.FontProperties(fname=font_url).get_name()
    rc('font', family=font_name)

# %matplotlib inline

if(png_name):
    korea = np.array(Image.open("img/"+png_name))
else:
    korea = np.array(Image.open("img/"+category+"1.png"))

image_colors = ImageColorGenerator(korea)


wordcloud = WordCloud(font_path=font_url,
                     relative_scaling = 0.2, mask=korea,
                     background_color=background_color_n,
                      min_font_size=1, max_font_size=max_font_size_n
                     ).generate_from_frequencies(tmp_data)
plt.figure(figsize=(30,30))

#설정에 맞게 색깔 변경
if state == "no":
    plt.imshow(wordcloud)
elif state == "img":
    plt.imshow(wordcloud.recolor(color_func=image_colors) ,interpolation='bilinear')
elif state == "grey":
    plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3) ,interpolation='bilinear')
else:
    plt.imshow(wordcloud.recolor(color_func=lambda *args, **kwargs: state, random_state=3) ,interpolation='bilinear')

plt.axis("off")
plt.show()

# %%
make_cloud("경제민주화", "경제민주화.png",state="no", background_color_n='white', max_font_size_n = 150)
# Out:
# 47167
# ok

# %%
make_cloud("경제민주화", "경제민주화.png",state="grey", background_color_n='black', max_font_size_n = 150)
# Out:
# 47167
# ok

# %%
make_cloud("경제민주화", "경제민주화.png",state="img", background_color_n='white', max_font_size_n = 150)
# Out:
# 47167
# ok

# %% [markdown]
# https://pixabay.com/ko/vectors/%EB%8F%88-%EA%B0%80%EB%B0%A9-%ED%98%84%EA%B8%88-%ED%86%B5%ED%99%94-%EC%9E%AC%EC%82%B0-576443/

# %%
make_cloud("교통/건축/국토", "건축.png",state="img", background_color_n='white', max_font_size_n = 150)
# Out:
# 53910
# ok

# %% [markdown]
# https://pixabay.com/ko/vectors/%EC%8B%9C%EA%B3%A8%EC%A7%91-%EC%A7%91-%ED%99%88-%EA%B1%B4%EB%AC%BC-%EC%A1%B0%EA%B8%88-160367/

# %%
make_cloud("미래", "미래.png",state="img", background_color_n='white', max_font_size_n = 100)
# Out:
# 31265
# ok

# %% [markdown]
# https://pixabay.com/ko/vectors/%EB%A1%9C%EC%BC%93-%EC%9A%B0%EC%A3%BC%EC%84%A0-%EA%B3%B5%EA%B0%84-%EC%8B%9C%EC%9E%91-312767/
